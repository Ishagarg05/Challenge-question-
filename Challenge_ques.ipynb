# %% [markdown]
# <a href="https://colab.research.google.com/github/Ishagarg05/Challenge-question-/blob/main/Challenge_ques.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Time question
import time
t1=time.time()

for i in range (100000):
 for j in range (100000):
  t2=time.time()
  print("Total Time",t2-t1)
# Out:
# Streaming output truncated to the last 5000 lines.
# Total Time 450.120014667511
# Total Time 450.1200439929962
# Total Time 450.1200807094574
# Total Time 450.12010979652405
# Total Time 450.1201364994049
# Total Time 450.12016201019287
# Total Time 450.12018871307373
# Total Time 450.12021589279175
# Total Time 450.1202437877655
# Total Time 450.1202886104584
# Total Time 450.1203143596649
# Total Time 450.12034130096436
# Total Time 450.12036967277527
# Total Time 450.1203980445862
# Total Time 450.120423078537
# Total Time 450.1204500198364
# Total Time 450.1204762458801
# Total Time 450.1205027103424
# Total Time 450.12053322792053
# Total Time 450.1205608844757
# Total Time 450.12058782577515
# Total Time 450.1206147670746
# Total Time 450.120641708374
# Total Time 450.12066864967346
# Total Time 450.1207046508789
# Total Time 450.12073254585266
# Total Time 450.12075877189636
# Total Time 450.1207857131958
# Total Time 450.1208176612854
# Total Time 450.1208448410034
# ...

# %%
# 1. Write a python program to sort the list of heterogeneous data.
#e.g.
#L = ["Ram", 1, "Shyam", 2, "Aman", 3]
#print(L)
#L.sort()
#print(L)
# Above code gives error. Correct it.

L = ["Ram", 1, "Shyam", 2, "Aman", 3]
L = [str(i) for i in L]
L1= []
for i in L:
  try:
   L1.append(int(i))
  except:
        L1.append(i)
print(L)
L.sort()
print(L)
L.sort()
print(L1)
